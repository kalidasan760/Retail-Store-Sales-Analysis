# %% [markdown]
# # Retail Store Sales Analysis
# ## step 1 : Data Loading and Initial Overview
# ## Project Overview
# ### Domain:Retail Analytics
# ### Objective
# This project analyzes retail store transaction data to understand sales performance, customer purchasing behavior, category-wise revenue distribution, and payment preferences. The goal is to uncover patterns and trends that help improve business decision-making in a retail environment.
#
# ### Business problem
# Retail businesses deal with multiple product categories, varying customer demand, and different payment methods. Understanding how customers
# purchase products and which categories drive revenue is critical for:
#
# 	•	Improving inventory planning
#
# 	•	Identifying high-performing and low-performing product categories
#
# 	•	Optimizing pricing and promotions
#
# 	•	Enhancing customer purchase experience
#
# 	•	Increasing overall revenue and operational efficiency

# %% [markdown]
# ## Dataset information
# ### Dataset Name:retail_store_sales.csv
# ### Dataset Description:
# This dataset contains detailed transaction-level data from a retail store. Each record represents a single customer transaction and includes:
#
# 	•	Product category details
#
# 	•	Price and quantity information
#
# 	•	Total amount spent
#
# 	•	Payment method used
#
# 	•	Store location
#
# 	•	Transaction date
#
# 	•	Discount information

# %% [markdown]
# ## Data Loading and Intial  Overview
# •	Load the dataset into the environment
#
# •	Examine the structure and size of the data
#
# •	Understand column names and data types
#
# •	Perform initial data quality checks
#
# •	Identify potential issues that need cleaning

# %% [markdown]
# ## Import Required Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Pandas Display Settings

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## Data Source and Loading
# ### Data Source: Retail Store Sales Dataset
# ### Source Link:Kaggle –https://www.kaggle.com/datasets/ahmedmohamed2003/retail-store-sales-dirty-for-data-cleaning
#
# ## Loading Objectives
# •	Total number of transactions (rows)
#
# •	Total number of features (columns)
#
# •	Structure and format of each column
#
# •	Overall data quality

# %% [markdown]
# ## Load the Dataset

# %%
df = pd.read_csv("G:\\My Drive\\MAIN PROJECT(ENTRI)\\Retailstore_Sales_cleaned.csv")
print("Dataset loaded successfully!")
print("="*70)
print(f"Dataset Shape: {df.shape[0]:,} rows × {df.shape[1]} columns")
# Out:
# Dataset loaded successfully!
# ...
# Dataset Shape: 12,575 rows × 11 columns

# %% [markdown]
# ## First Look at the Data
# To understand the structure and actual values in the dataset, we inspect the first few rows.
#
# ### Why this matters
# •	Verifies that the data loaded correctly
#
# •	Helps understand column formats
#
# •	Identifies obvious data quality issues

# %%
print("First 10 rows of the dataset:")
df.head(10)
# Out:
# First 10 rows of the dataset:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT           18.50
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK           29.00
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT           21.50
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV           27.50
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD           12.50
# 5    TXN_7482416     CUST_09     Patisserie    Item_2_BEV           23.00
# 6    TXN_3652209     CUST_07           Food   Item_1_FOOD            5.00
# 7    TXN_1372952     CUST_21      Furniture    Item_2_BEV           33.50
# 8    TXN_9728486     CUST_23      Furniture   Item_16_FUR           27.50
# 9    TXN_2722661     CUST_25       Butchers   Item_22_BUT           36.50
#
#    Quantity  Total Spent  Payment Method  Location Transaction Date  \
# ...

# %% [markdown]
# ## Last Rows of the Dataset
# Examining the last few rows helps ensure:
#
# •	The dataset loaded completely
#
# •	No corruption at the end of the file
#
# •	Consistent data structure throughout

# %%
print("Last 10 rows of the dataset:")
df.tail(10)
# Out:
# Last 10 rows of the dataset:
#       Transaction ID Customer ID                            Category  \
# 12565    TXN_1712895     CUST_07  Computers and electric accessories
# 12566    TXN_6298574     CUST_01                       Milk Products
# 12567    TXN_4890318     CUST_25                            Butchers
# 12568    TXN_1096134     CUST_06                                Food
# 12569    TXN_2318174     CUST_18                          Patisserie
# 12570    TXN_9347481     CUST_18                          Patisserie
# 12571    TXN_4009414     CUST_03                           Beverages
# 12572    TXN_5306010     CUST_11                            Butchers
# 12573    TXN_5167298     CUST_04                           Furniture
# 12574    TXN_2407494     CUST_23                                Food
#
#               Item  Price Per Unit  Quantity  Total Spent  Payment Method  \
# 12565   Item_2_CEA            6.50      5.00        32.50  Digital Wallet
# ...

# %% [markdown]
# ## Dataset Information and Data Types
# Understanding data types is crucial for:
#
# •	Identifying columns that need type conversion
#
# •	Planning analysis techniques
#
# •	Detecting missing values
#
# •	Estimating memory usage

# %%
print("Dataset Information:")
print("="*70)
df.info()
# Out:
# Dataset Information:
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12575 entries, 0 to 12574
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    12575 non-null  object
#  1   Customer ID       12575 non-null  object
#  2   Category          12575 non-null  object
#  3   Item              12575 non-null  object
#  4   Price Per Unit    12575 non-null  float64
#  5   Quantity          12575 non-null  float64
#  6   Total Spent       12575 non-null  float64
#  7   Payment Method    12575 non-null  object
#  8   Location          12575 non-null  object
#  9   Transaction Date  12575 non-null  object
#  10  Discount Applied  12575 non-null  bool
# dtypes: bool(1), float64(3), object(7)
# memory usage: 994.8+ KB

# %% [markdown]
# ## Key Observations
# •	The dataset contains both numerical and categorical features
#
# •	Numerical columns include:
#
# •	Price
#
# •	Quantity
#
# •	Total spent
#
# •	Categorical columns include:
#
# •	Category
#
# •	Payment method
#
# •	Location
#
# •	Transaction date is a date-related feature
#
# •	Some columns may require type correction in preprocessing

# %% [markdown]
# ## Column Names and Descriptions
#
# ### Transaction Details
# •	Transaction ID: Unique identifier for each transaction
#
# •	Customer ID: Unique identifier for each customer
#
# ### Product Information
# •	Category: Product category
#
# •	Item: Specific product name
#
# •	Price: Price per unit
#
# •	Quantity: Number of units purchased
#
# •	Total spent: Total transaction amount
#
# ### Payment & Store Information
# •	Payment method: Mode of payment used
#
# •	Location: Store or city location
#
# •	Discount applied: Whether a discount was applied
#
# ### Time Information
# •	Transaction date: Date of purchase

# %% [markdown]
# ## Statistical Summary of Numerical Features
# ### The describe() function provides statistical insights such as:
# •	Mean and median values
#
# •	Data spread (standard deviation)
#
# •	Minimum and maximum values
#
# •	Quartiles (25%, 50%, 75%)

# %%
print("Statistical Summary of Numerical Features:")
print("="*70)
df.describe()
# Out:
# Statistical Summary of Numerical Features:
# ...
#        Price Per Unit  Quantity  Total Spent
# count        12575.00  12575.00     12575.00
# mean            23.35      5.56       130.11
# std             10.48      2.79        92.33
# min              5.00      1.00         5.00
# 25%             14.00      3.00        55.00
# 50%             23.00      6.00       111.00
# 75%             32.00      8.00       192.00
# max             41.00     10.00       410.00

# %% [markdown]
# ## Why this is important
# •	Identifies outliers
#
# •	Shows distribution of sales and quantities
#
# •	Helps validate realistic values

# %% [markdown]
# ## Data Quality Checks
#
# ### Missing Values Check
# Missing values can affect analysis accuracy and must be identified early.

# %%
print("Missing Values Summary:")
missing_values = df.isnull().sum()
print(missing_values)
print("="*70)

if missing_values.sum() > 0:
    print("Columns with missing values:")
    print(missing_values[missing_values > 0])
else:
    print("No missing values found in the dataset.")
# Out:
# Missing Values Summary:
# Transaction ID      0
# Customer ID         0
# Category            0
# Item                0
# Price Per Unit      0
# Quantity            0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# Discount Applied    0
# dtype: int64
# ...
# No missing values found in the dataset.

# %% [markdown]
# ## Duplicate Records Check
# Duplicate records can distort sales calculations and insights.

# %%
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")

if duplicates > 0:
    print("Warning: Duplicate records detected!")
else:
    print("No duplicate rows found in the dataset.")
# Out:
# Number of duplicate rows: 0
# No duplicate rows found in the dataset.

# %% [markdown]
# ## Summary of Findings
#
# ### Dataset Overview
# •	The dataset contains multiple retail transactions
#
# •	Each row represents a unique purchase
#
# •	Multiple product categories and payment methods are included
#
# ### Data Quality Observations
# •	Minor missing values may exist in some columns
#
# •	No major structural issues detected
#
# •	Some columns may require data type conversion
#
# ### Business Readiness
# •	The dataset is suitable for:
#
# •	Sales trend analysis
#
# •	Category-wise performance evaluation
#
# •	Payment behavior analysis
